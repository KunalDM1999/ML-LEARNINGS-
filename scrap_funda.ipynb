# %% [markdown]
# <a href="https://colab.research.google.com/github/KunalDM1999/ML-LEARNINGS-/blob/main/scrap_funda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlopen


url = urlopen("https://en.wikipedia.org/wiki/2024_Chile_wildfires")

url.read()
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>2024 Chile wildfires - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled v
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

url = urlopen("https://en.wikipedia.org/wiki/2024_Chile_wildfires")
soup = BeautifulSoup(url.read(),'html.parser')

soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>2024 Chile wildfires - Wikipedia</title>
# ...

# %%
soup.title
# Out:
# <title>2024 Chile wildfires - Wikipedia</title>

# %%
soup.img
# Out:
# <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>

# %%
soup.find_all('a')
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>,
#  <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>,
#  <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a>,
#  <a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a>,
#  <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a>,
#  <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a>,
#  <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a>,
# ...

# %%
soup.find_all('img')
# Out:
# [<img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>,
#  <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>,
#  <img alt="The Free Encyclopedia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" style="width: 7.3125em; height: 0.8125em;" width="117"/>,
# ...

# %%
p=soup.find_all('img')
len(p)
# Out:
# 10

# %%
soup.find_all('img')[0]
# Out:
# <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>

# %%
soup.find_all('table')[0]
# Out:
# <table class="infobox vevent"><tbody><tr><th class="infobox-above summary" colspan="2" style="background-color: sandybrown;">2024 Chile wildfires</th></tr><tr><td class="infobox-image" colspan="2"><span class="mw-default-size" typeof="mw:File/Frameless"><a class="mw-file-description" href="/wiki/File:Incendios_forestales_de_Chile_de_2024-02-02T19_40_00Z.jpg"><img class="mw-file-element" data-file-height="4624" data-file-width="2571" decoding="async" height="396" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Incendios_forestales_de_Chile_de_2024-02-02T19_40_00Z.jpg/220px-Incendios_forestales_de_Chile_de_2024-02-02T19_40_00Z.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Incendios_forestales_de_Chile_de_2024-02-02T19_40_00Z.jpg/330px-Incendios_forestales_de_Chile_de_2024-02-02T19_40_00Z.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/21/Incendios_forestales_de_Chile_de_2024-02-02T19_40_00Z.jpg/440px-Incendios_forestales_de_Chile_de_2024-02-02T19_
# ...

# %%
soup.find_all('td',{'class':'infobox-data'})
# Out:
# [<td class="infobox-data"><span class="nowrap">1–5 February 2024<sup class="reference" id="cite_ref-independent_1-0"><a href="#cite_note-independent-1">[1]</a></sup></span></td>,
#  <td class="infobox-data location"><style data-mw-deduplicate="TemplateStyles:r1126788409">.mw-parser-output .plainlist ol,.mw-parser-output .plainlist ul{line-height:inherit;list-style:none;margin:0;padding:0}.mw-parser-output .plainlist ol li,.mw-parser-output .plainlist ul li{margin-bottom:0}</style><div class="plainlist"><ul><li>Chile</li><li>In the regions of:</li><li><a href="/wiki/Valpara%C3%ADso_Region" title="Valparaíso Region">Valparaíso</a></li><li><a href="/wiki/O%27Higgins_Region" title="O'Higgins Region">O'Higgins</a></li><li><a href="/wiki/Maule_Region" title="Maule Region">Maule</a></li></ul></div></td>,
#  <td class="infobox-data">165<sup class="reference" id="cite_ref-gulf_2-0"><a href="#cite_note-gulf-2">[2]</a></sup></td>,
#  <td class="infobox-data">6,800 hectares</td>,
# ...

# %%
soup.find_all('img',{'width':220,'height':396})
# Out:
# [<img class="mw-file-element" data-file-height="4624" data-file-width="2571" decoding="async" height="396" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Incendios_forestales_de_Chile_de_2024-02-02T19_40_00Z.jpg/220px-Incendios_forestales_de_Chile_de_2024-02-02T19_40_00Z.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/Incendios_forestales_de_Chile_de_2024-02-02T19_40_00Z.jpg/330px-Incendios_forestales_de_Chile_de_2024-02-02T19_40_00Z.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/21/Incendios_forestales_de_Chile_de_2024-02-02T19_40_00Z.jpg/440px-Incendios_forestales_de_Chile_de_2024-02-02T19_40_00Z.jpg 2x" width="220"/>]

# %% [markdown]
# ## ** use of cookies **
#
# *  new website
# *   new data

# %%
from urllib.request import URLopener
from bs4 import BeautifulSoup
u = urlopen("https://www.worldometers.info/world-population/population-by-country/")

sup=BeautifulSoup(u.read(),'html.parser')
sup
# Out:
# <!DOCTYPE html>
# ...

# %%
sup.text
# Out:
# "\n       Population by Country (2024) - Worldometer                     Coronavirus Population    WPopulation Population by Country Countries in the world by population (2024)This list includes both countries and dependent territories. Data based on the latest United Nations Population Division estimates. Click on the name of the country or dependency for current estimates (live population clock), historical data, and projected figures.  See also: World Population   Updated on July 16, 2023 with the latestJuly 2023-July 2024 estimates from the 2022 U.N. Revision    # Country (or dependency) Population (2023) Yearly Change Net Change Density (P/Km²) Land Area (Km²) Migrants (net) Fert. Rate Med. Age Urban Pop % World Share     1 India 1,428,627,663 0.81 % 11,454,490 481 2,973,190 -486,136 2.0 28 36 % 17.76 %   2 China 1,425,671,352 -0.02 % -215,985 152 9,388,211 -310,220 1.2 39 65 % 17.72 %   3 United States 339,996,563 0.50 % 1,706,706 37 9,147,420 999,700 1.7 38 83 % 4.23 %   4 Ind
# ...

# %%
sup.find_all('table')[0].find_all('tr')[1]
# Out:
# <tr> <td>1</td> <td style="font-weight: bold; font-size:15px; text-align:left"><a href="/world-population/india-population/">India</a></td> <td style="font-weight: bold;">1,428,627,663</td> <td>0.81 %</td> <td>11,454,490</td> <td>481</td> <td>2,973,190</td> <td>-486,136</td> <td>2.0</td> <td>28</td> <td>36 %</td> <td>17.76 %</td> </tr>

# %%
sup.find_all('table')[0].find_all('tr')[1].find_all('td')[1].text
# Out:
# 'India'

# %%
l=len(sup.find_all('table')[0].find_all('tr'))
l
# Out:
# 235

# %%
for i in range(1,l):
   print(sup.find_all('table')[0].find_all('tr')[i].find_all('td')[1].text,end='  :  ')
   print(sup.find_all('table')[0].find_all('tr')[i].find_all('td')[2].text,end='  :  ')
   print(sup.find_all('table')[0].find_all('tr')[i].find_all('td')[3].text)

# %% [markdown]
# # **movie scraping**

# %%
cookies = {

     '_gid':'GA1.2.648724963.1718958200',
     'uvts':'0d9aaa70-709f-4836-4bf3-24713044d416',
     'uvts':'0d9aaa70-709f-4836-4bf3-24713044d416',
     'ml4_session':'8428556c172aa973e6c01e458dd95763218aa8a2_d0d66d27-7daa-4cac-a81f-74a5998d73d2',
     '_gat_gtag_UA_42433938_3':'1',
     '_ga':'GA1.1.242449126.1718958197',
     '_ga_TY2XJRE9PE':'GS1.1.1718958196.1.1.1718960145.0.0.0'
}
ur = urlopen("https://movielens.org/home")

su=BeautifulSoup(ur.read(),'html.parser')
su

# %%
import requests
from bs4  import BeautifulSoup
cookies = {

     '_gid':'GA1.2.648724963.1718958200',
     'uvts':'0d9aaa70-709f-4836-4bf3-24713044d416',
     'uvts':'0d9aaa70-709f-4836-4bf3-24713044d416',
     'ml4_session':'8428556c172aa973e6c01e458dd95763218aa8a2_d0d66d27-7daa-4cac-a81f-74a5998d73d2',
     '_gat_gtag_UA_42433938_3':'1',
     '_ga':'GA1.1.242449126.1718958197',
     '_ga_TY2XJRE9PE':'GS1.1.1718958196.1.1.1718960145.0.0.0'
}
ur = "https://movielens.org/api/users/me/frontpage"

su=requests.get(ur,cookies = cookies)

# %%
su.text
# Out:
# '{"status":"success","data":{"listOfSearchResults":[{"title":"top picks","description":"MovieLens recommends these movies","url":"/explore/top-picks","searchResults":[{"movieId":195159,"rec_val_type":"","tstamp":null,"movie":{"movieId":195159,"tmdbMovieId":324857,"imdbMovieId":"4633694","title":"Spider-Man: Into the Spider-Verse","originalTitle":"Spider-Man: Into the Spider-Verse","mpaa":"PG","runtime":117,"releaseDate":"2018-12-06","dvdReleaseDate":null,"genres":["Animation","Action","Adventure","Science Fiction"],"languages":["English","日本語","Español"],"directors":["Bob Persichetti","Peter Ramsey","Rodney Rothman"],"actors":["Shameik Moore","Jake Johnson","Hailee Steinfeld","Mahershala Ali","Brian Tyree Henry","Lily Tomlin","Luna Lauren Velez","Zoë Kravitz","John Mulaney","Kimiko Glenn","Nicolas Cage","Kathryn Hahn","Liev Schreiber","Chris Pine","Natalie Morales","Edwin H. Bravo","Oscar Isaac","Greta Lee","Stan Lee","Jorma Taccone","Joaquín Cosío","Marvin \'Krondon\' Jones III","Ki
# ...

# %%
import json
x=json.loads(su.content)
x
# Out:
# {'status': 'success',
#  'data': {'listOfSearchResults': [{'title': 'top picks',
#     'description': 'MovieLens recommends these movies',
#     'url': '/explore/top-picks',
#     'searchResults': [{'movieId': 195159,
#       'rec_val_type': '',
#       'tstamp': None,
#       'movie': {'movieId': 195159,
#        'tmdbMovieId': 324857,
#        'imdbMovieId': '4633694',
#        'title': 'Spider-Man: Into the Spider-Verse',
#        'originalTitle': 'Spider-Man: Into the Spider-Verse',
#        'mpaa': 'PG',
#        'runtime': 117,
#        'releaseDate': '2018-12-06',
#        'dvdReleaseDate': None,
#        'genres': ['Animation', 'Action', 'Adventure', 'Science Fiction'],
#        'languages': ['English', '日本語', 'Español'],
#        'directors': ['Bob Persichetti', 'Peter Ramsey', 'Rodney Rothman'],
#        'actors': ['Shameik Moore',
#         'Jake Johnson',
#         'Hailee Steinfeld',
#         'Mahershala Ali',
#         'Brian Tyree Henry',
#         'Lily Tomlin',
# ...

# %%
x['data']['listOfSearchResults'][0]['searchResults'][0]['movie']['title']
# Out:
# 'Spider-Man: Into the Spider-Verse'

# %%
for i in range(8):
  print(x['data']['listOfSearchResults'][0]['searchResults'][i]['movie']['title'])
# Out:
# Spider-Man: Into the Spider-Verse
# Star Wars
# The Empire Strikes Back
# Raiders of the Lost Ark
# The Princess Bride
# Return of the Jedi
# The Shawshank Redemption
# Back to the Future
